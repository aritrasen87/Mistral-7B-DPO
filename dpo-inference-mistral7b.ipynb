# %% [markdown]
# ### Inference Notebook:
#
# - Part of YouTube( www.YouTube.com/@AritraSen ) video tutorials for DPO training for Mistral7B LLM
# - Mistral 7B DPO Training notebook: https://github.com/aritrasen87/Mistral-7B-DPO/blob/main/dpo-training.ipynb
# - Model saved in hugging huggingface notebook: https://huggingface.co/aritrasen/mistral-dpo
# - Dataset used for model DPO training: Dahoas/full-hh-rlhf ( https://huggingface.co/datasets/Dahoas/full-hh-rlhf )

# %%
! pip install torch==2.0.1 transformers peft accelerate trl bitsandbytes optimum auto-gptq --q

# %%
model_path = 'aritrasen/mistral-dpo'

# %%
from peft import AutoPeftModelForCausalLM
from transformers import GenerationConfig
from transformers import AutoTokenizer
import torch
tokenizer = AutoTokenizer.from_pretrained(model_path)


model = AutoPeftModelForCausalLM.from_pretrained(
    model_path,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map="cuda")

generation_config = GenerationConfig(
    do_sample=True,
    top_k=1,
    temperature=0.2,
    max_new_tokens=256,
    pad_token_id=tokenizer.eos_token_id
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/630 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# adapter_config.json:   0%|          | 0.00/587 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ...

# %%
inputs = tokenizer("""How to repair my phone which not turning on?""", return_tensors="pt").to("cuda")

# %%
# %%time
outputs = model.generate(**inputs, generation_config=generation_config)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# Out:
# How to repair my phone which not turning on?
#
# If your phone is not turning on, there are several things you can try to fix the problem. First, make sure that the phone is charged. If it is not, plug it in and wait for it to charge. If the phone still does not turn on, try resetting it by holding down the power button for 10 seconds. If that does not work, try removing the battery and reinserting it. If none of these solutions work, you may need to take the phone to a professional for repair.
# CPU times: user 1min 10s, sys: 28.1 s, total: 1min 38s
# Wall time: 1min 38s
